# %%
# Need to divide every audio file into 1 sec chunks before proceeding:
from pydub import AudioSegment
from pydub.utils import make_chunks
import glob

myaudio = AudioSegment.from_file("0_both/her_ga_r_det_godt_01_10_21/segment0005.wav" , "wav") 
chunk_length_ms = 1000 # pydub calculates in millisec
chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of one sec

#Export all of the individual chunks as wav files

# for i, chunk in enumerate(chunks):
#     chunk_name = "0_both_1s/chunk{0}.wav".format(i)
#     print("exporting", chunk_name)
#     chunk.export(chunk_name, format="wav")

# Split 0_both into 1 sec files
file_indx = 0
for filepath in glob.iglob('0_both/her_ga_r_det_godt_01_10_21/*.wav'):
    print(filepath)
    myaudio = AudioSegment.from_file(filepath , "wav")
    chunk_length_ms = 1000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of one sec
    for i, chunk in enumerate(chunks):
        chunk_name = "0_both_1s/chunk{0}.wav".format((5 * file_indx) + i)
        #print("exporting", chunk_name)
        chunk.export(chunk_name, format="wav")
        
    file_indx = file_indx + 1

# Split 1_esben into 1 sec files
file_indx = 0
for filepath in glob.iglob('1_esben/her_ga_r_det_godt_01_10_21/*.wav'):
    print(filepath)
    myaudio = AudioSegment.from_file(filepath , "wav")
    chunk_length_ms = 1000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of one sec
    for i, chunk in enumerate(chunks):
        chunk_name = "1_esben_1s/chunk{0}.wav".format((5 * file_indx) + i)
        #print("exporting", chunk_name)
        chunk.export(chunk_name, format="wav")
        
    file_indx = file_indx + 1
for filepath in glob.iglob('1_esben/her_ga_r_det_godt_03_09_21/*.wav'):
    print(filepath)
    myaudio = AudioSegment.from_file(filepath , "wav")
    chunk_length_ms = 1000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of one sec
    for i, chunk in enumerate(chunks):
        chunk_name = "1_esben_1s/chunk{0}.wav".format((5 * file_indx) + i)
        #print("exporting", chunk_name)
        chunk.export(chunk_name, format="wav")
        
    file_indx = file_indx + 1


# Split 2_peter into 1 sec files
file_indx = 0
for filepath in glob.iglob('2_peter/her_ga_r_det_godt_01_10_21/*.wav'):
    print(filepath)
    myaudio = AudioSegment.from_file(filepath , "wav")
    chunk_length_ms = 1000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of one sec
    for i, chunk in enumerate(chunks):
        chunk_name = "2_peter_1s/chunk{0}.wav".format((5 * file_indx) + i)
        #print("exporting", chunk_name)
        chunk.export(chunk_name, format="wav")
        
    file_indx = file_indx + 1
for filepath in glob.iglob('2_peter/her_ga_r_det_godt_03_09_21/*.wav'):
    print(filepath)
    myaudio = AudioSegment.from_file(filepath , "wav")
    chunk_length_ms = 1000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of one sec
    for i, chunk in enumerate(chunks):
        chunk_name = "2_peter_1s/chunk{0}.wav".format((5 * file_indx) + i)
        #print("exporting", chunk_name)
        chunk.export(chunk_name, format="wav")
        
    file_indx = file_indx + 1

# %%
# TODO:
# 1 - (DONE) Do FFT 
# 2 - Sort the frequencies to be in human vocal range to get a fixed 1D Vector size (Might be done in the function above)
# 3 - Put them in tensor format (data) with labels etc, so it can be used with pytorch classes and functions
# 4 - Create Augmentations for the dataset
# 5 - Create Datasets, validation sets, test sets, and loaders
# 6 - Modify the helper functions from class
# 7 - Create NN model
# 8 - Train
